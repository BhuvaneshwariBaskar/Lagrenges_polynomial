# %%
import numpy as np
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as mp
plt.style.use('seaborn-poster')

# %%
x1 = [0, 1, 2]
y1 = [1, 3, 2]
P1_coeff = [1,-1.5,.5]
P2_coeff = [0, 2,-1]
P3_coeff = [0,-.5,.5]

# get the polynomial function
P1 = poly.Polynomial(P1_coeff)
P2 = poly.Polynomial(P2_coeff)
P3 = poly.Polynomial(P3_coeff)

x_new = np.arange(-1.0, 3.1, 0.1)

fig = mp.figure(figsize = (10,8))
mp.plot(x_n, P1(x_n), 'g', label = 'P1')
mp.plot(x_n, P2(x_n), 'b', label = 'P2')
mp.plot(x_n, P3(x_n), 'r', label = 'P3')

mp.plot(x, np.ones(len(x1)), 'ko', x, np.zeros(len(x1)), 'ko')
mp.title('Lagrange Polynomials')
mp.xlabel('x')
mp.ylabel('y')
mp.grid()
mp.legend()
mp.show()

# %%
L = P1 + 3*P2 + 2*P3

fig = mp.figure(figsize = (10,8))
mp.plot(x_new, L(x_new), 'g', x, y, 'ro')
mp.title('Lagrange Polynomial')
mp.grid()
mp.xlabel('x')
mp.ylabel('y')
mp.show()
